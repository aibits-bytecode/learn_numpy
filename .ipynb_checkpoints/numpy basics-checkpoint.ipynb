# %% [markdown]
# ## Numpy learnings 😁

# %%
import numpy as np
a = np.array([2,1,3,22])

# %%
a[0]
# Out:
# 2

# %%
# this is looks like python list 
# the difference between list and numpy

# benifts -
# Require less memory 
# fast
# convinient  - works as the devooper want

# %%
import time
import sys

l = range(100)

# %%
sys.getsizeof(5)*len(l)
# Out:
# 2800

# %%
arr = np.arange(100)

# %%
arr.size*arr.itemsize
# Out:
# 800

# %% [markdown]
# ![numpy%20vs%20list.png](attachment:numpy%20vs%20list.png)

# %%
size = 10000000
l1 = range(size)
l2 = range(size)

arr1 = np.arange(size)
arr2 = np.arange(size)

# %%
start1 = time.time()
result = [(x+y) for x,y in zip(l1,l2)]
list_time = (time.time() - start1) * 1000

start2 = time.time()
result2 = arr1 + arr2
numpy_time = (time.time() - start2)*1000

# %%
print("python list took : ",list_time)
print("Numpy took :",numpy_time)
# Out:
# python list took :  487.0409965515137
# Numpy took : 64.76402282714844

# %% [markdown]
# ### 2 dimentional array

# %%
n1d = np.array([2,3,4,5,6])
print(n1d.ndim)
# Out:
# 1

# %%
n2d = np.array([
                [1,2],
                [3,2],
                [3,4]
])
print(n2d.ndim)
# Out:
# 2

# %%
# Float array

floatarr = np.array([2,3,4,5], dtype = np.float64)

# %%
floatarr.dtype
# Out:
# dtype('float64')

# %%
floatarr
# Out:
# array([2., 3., 4., 5.])

# %%
# numpy array creations 
# this returns numbers between start and end
arr1  = np.arange(1,5)
print(arr1)
# Out:
# [1 2 3 4]

# %%
# this returns numbers between start and end but jumps by 2
arr2 = np.arange(1,5,2)
print(arr2)
# Out:
# [1 3]

# %%
# this return 10 numbers between 1 and 5
arr3 = np.linspace(1,5,10)
print(arr3)
# Out:
# [1.         1.44444444 1.88888889 2.33333333 2.77777778 3.22222222
#  3.66666667 4.11111111 4.55555556 5.        ]

# %%
arr = np.array([
    [1,2],
    [2,3],
    [3,4]
])

print(arr.shape)
# Out:
# (3, 2)

# %%
# thsi returns the reshaped array
rearr = arr.reshape(2,3)
rearr
# Out:
# array([[1, 2, 2],
#        [3, 3, 4]])

# %%
# this returns flatterned array
flatarr = arr.ravel()
flatarr
# Out:
# array([1, 2, 2, 3, 3, 4])

# %%
arr.min()
# Out:
# 1

# %%
arr.max()
# Out:
# 4

# %% [markdown]
# ![numpy%20axis.png](attachment:numpy%20axis.png)

# %%
newarr = np.array([
    [1,2],
    [3,4],
    [5,6]
])
newarr.sum(axis=0)
# Out:
# array([ 9, 12])

# %%
np.sqrt(newarr)
# Out:
# array([[1.        , 1.41421356],
#        [1.73205081, 2.        ],
#        [2.23606798, 2.44948974]])

# %% [markdown]
# ## Numpy Slicing/Indexing and mutch more ☺️
